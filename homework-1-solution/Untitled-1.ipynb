# %%
import functions
p = functions.Product(functions.Polynomial(2,0,0),functions.Polynomial(1,0,0))
g = functions.Polynomial(1,0,0,0,0) #check if it equals to x^4
p.plot(color='red')
g.plot(color='blue',linestyle = '--')
p.__str__()
# Out:
# 'AbstractFunction'

# %%
functions.Polynomial(2,1,0,4)
# Out:
# '2({0})^3 + ({0})^2 + 4'
